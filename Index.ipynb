# %% [markdown]
# # My Portfolio
#
# Hi everyone! My name is Aramina P. Galario, and I am a 4th-year Data Science student. I am particularly interested in Exploratory Data Analysis and Data Visualization, as I enjoy discovering insights from data and presenting them in a clear and meaningful way. Currently, I use Jupyter Notebook, Python, and R for my data science work and projects. I look forward to further developing my skills and gaining more experience in the field of Data Science.
